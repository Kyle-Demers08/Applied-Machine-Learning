# %%
#import packages
import pandas as pd
import numpy as np
from sklearn.impute import SimpleImputer
from scipy.stats import norm
import random
from scipy.stats import beta
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('L1Data.csv') #import dataset

# %%
data.head(20)
# Out:
#         Class   Age  Funds Sale
# 0    Freshmen  18.0  600.0   No
# 1    Freshmen  18.0  500.0   No
# 2    Freshmen  18.0  600.0   No
# 3      Senior  23.0  800.0   No
# 4      Junior  21.0  400.0  Yes
# 5    Freshmen  19.0  600.0   No
# 6    Freshmen  20.0  600.0   No
# 7      Senior  24.0    NaN  Yes
# 8   Sophomore  23.0  620.0  Yes
# 9   Sophomore  25.0  800.0  Yes
# 10     Junior  21.0  900.0   No
# 11     Junior  21.0  650.0  Yes
# 12  Sophomore   NaN  500.0   No
# 13     Junior  21.0  800.0   No
# 14     Junior  20.0  650.0  Yes
# 15  Sophomore  21.0  580.0  Yes
# 16  Sophomore  20.0  800.0  Yes
# 17     Senior  26.0    NaN  Yes
# 18     Senior  25.0    NaN  Yes
# 19     Senior  41.0    NaN  Yes

# %% [markdown]
# ### Question 1: ###

# %%
imputing_config = SimpleImputer(missing_values=np.nan,strategy='median')
imp = imputing_config.fit(data[["Age"]])
data[["Age"]] = imp.transform(data[["Age"]])
data
# Out:
#         Class   Age  Funds Sale
# 0    Freshmen  18.0  600.0   No
# 1    Freshmen  18.0  500.0   No
# 2    Freshmen  18.0  600.0   No
# 3      Senior  23.0  800.0   No
# 4      Junior  21.0  400.0  Yes
# 5    Freshmen  19.0  600.0   No
# 6    Freshmen  20.0  600.0   No
# 7      Senior  24.0    NaN  Yes
# 8   Sophomore  23.0  620.0  Yes
# 9   Sophomore  25.0  800.0  Yes
# 10     Junior  21.0  900.0   No
# 11     Junior  21.0  650.0  Yes
# 12  Sophomore  21.0  500.0   No
# 13     Junior  21.0  800.0   No
# 14     Junior  20.0  650.0  Yes
# 15  Sophomore  21.0  580.0  Yes
# 16  Sophomore  20.0  800.0  Yes
# 17     Senior  26.0    NaN  Yes
# 18     Senior  25.0    NaN  Yes
# 19     Senior  41.0    NaN  Yes
# 20  Sophomore  21.0  500.0   No
# 21   Freshmen  18.0  500.0   No
# 22   Freshmen  18.0  500.0   No
# 23   Freshmen  18.0  600.0   No

# %% [markdown]
# ### Question 5 ###

# %%
data_normal = norm.rvs(size=1000,loc=3,scale=2)

# %%
n = 1000
x = norm.rvs(size= n,loc=3,scale=2,random_state = 123)
count = ((x > -1) & (x < 1)) 
sum(count / n)
# Out:
# 0.1470000000000001

# %% [markdown]
# ### Question 10: ###

# %%
a, b = 1.2, 1.8
loc = 3 #refers to where the distribution starts
scale = 2 #by how much you multiply the invterval from 0 to one so two means 0 to two but loc -1 makes it -1 to 1
mean, var, skew, kurt = beta.stats(a, b,loc = loc, scale = scale, moments='mvsk')
x = np.linspace(beta.ppf(0.01, a, b,loc=loc),beta.ppf(0.99, a, b,loc = loc, scale = scale), 100)
r = beta.rvs(a, b,loc=loc,scale= scale, size=1000)
plt.hist(r, density=True, edgecolor='black',alpha=0.5)
plt.plot(x, beta.pdf(x, a, b,loc = loc, scale= scale), 'r-', lw=3)
# plt.legend(loc='best', frameon=False)
plt.title("Example for a beta distribution")
plt.show()
