# %%
from sklearn import svm
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('MedicalData.csv')

# %%
data
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
# ...

# %%
y = data['diagnosis']
x = data[['radius_mean','texture_mean']]

# %%
X_train, X_test, y_train, y_test = train_test_split(y.values.reshape(-1,1),x.values, test_size=0.3, random_state=123)

# %%
eps = .22
C = 1
model = SVR(kernel='linear',C=C,epsilon=eps)

# %%
model.fit(y.values.reshape(-1,1),x.values)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [24], in <cell line: 1>()
# ----> 1 model.fit(y.values.reshape(-1,1),x.values)
#
# File /opt/conda/lib/python3.9/site-packages/sklearn/svm/_base.py:190, in BaseLibSVM.fit(self, X, y, sample_weight)
#     188     check_consistent_length(X, y)
#     189 else:
# --> 190     X, y = self._validate_data(
#     191         X,
#     192         y,
#     193         dtype=np.float64,
#     194         order="C",
#     195         accept_sparse="csr",
#     196         accept_large_sparse=False,
#     197     )
#     199 y = self._validate_targets(y)
#     201 sample_weight = np.asarray(
#     202     [] if sample_weight is None else sample_weight, dtype=np.float64
#     203 )
#
# File /opt/conda/lib/python3.9/site-packages/sklearn/base.py:581, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, **check_params)
# ...

# %%
avgRecall = []
# Classification and ROC analysis

# Run classifier with cross-validation and plot ROC curves
cv = StratifiedKFold(n_splits=10, shuffle = True, random_state = 123)
classifier = SVR(kernel='rbf',C=1, gamma=0.22)

tprs = []
aucs = []
mean_fpr = np.linspace(0, 1, 100)

for i, (train, test) in enumerate(cv.split(x, y)):
    classifier.fit(x[X_train], y[y_train])
    report = classification_report(y[test],classifier.predict(x[test]),output_dict=True)
    avgPrecision.append(report['1']['precision'])
    avgRecall.append(report['1']['recall'])
    y_pred_proba = classifier.predict_proba(x)[::,1]
    print('finished running KFold ' + str(i))
print('the average precision across 10 KFolds is: ' + str(np.mean(avgPrecision)) + ' and the average recall is: ' + str(np.mean(avgRecall)) + ' using Thunder SVM.')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [20], in <cell line: 12>()
#      10 mean_fpr = np.linspace(0, 1, 100)
#      12 for i, (train, test) in enumerate(cv.split(x, y)):
# ---> 13     classifier.fit(x[X_train], y[y_train])
#      14     report = classification_report(y[test],classifier.predict(x[test]),output_dict=True)
#      15     avgPrecision.append(report['1']['precision'])
#
# File /opt/conda/lib/python3.9/site-packages/pandas/core/frame.py:3511, in DataFrame.__getitem__(self, key)
#    3509     if is_iterator(key):
#    3510         key = list(key)
# -> 3511     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3513 # take() does not accept boolean indexers
#    3514 if getattr(indexer, "dtype", None) == bool:
#
# ...

# %%
# ?SVR
# Out:
# Init signature:
# SVR(
#     *,
#     kernel='rbf',
#     degree=3,
#     gamma='scale',
#     coef0=0.0,
#     tol=0.001,
#     C=1.0,
#     epsilon=0.1,
#     shrinking=True,
#     cache_size=200,
#     verbose=False,
#     max_iter=-1,
# )
# Docstring:
# Epsilon-Support Vector Regression.
#
# The free parameters in the model are C and epsilon.
#
# The implementation is based on libsvm. The fit time complexity
# is more than quadratic with the number of samples which makes it hard
# to scale to datasets with more than a couple of 10000 samples. For large
# datasets consider using :class:`~sklearn.svm.LinearSVR` or
# :class:`~sklearn.linear_model.SGDRegressor` instead, possibly after a
# :class:`~sklearn.kernel_approximation.Nystroem` transformer.
#
# Read more in the :ref:`User Guide <svm_regression>`.
#
# Parameters
# ----------
# kernel : {'linear', 'poly', 'rbf', 'sigmoid', 'precomputed'} or callable,          default='rbf'
# ...
